# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashwant-SriSai/Shakesphere_Copy_Cat/blob/main/text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imports
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Embedding,Dropout
from tensorflow.keras.optimizers import RMSprop
import random
import sys

# %%
#Load he Shakesphere's Dataset
print("Downloading Sakesphere's Data....")
path = tf.keras.utils.get_file('shakespeare.txt',
    origin='https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')
with open(path,encoding="utf-8") as f:
  text=f.read().lower() # why lower? so that model won't have to remember that both "a" and "A" or same.
# lets take first 200,000 characters for our vocabulary
text=text[:200000]
print(f'Corpus Length:{len(text)}')
# Out:
# Downloading Sakesphere's Data....
# Corpus Length:200000

# %%
#Map characters to integers
# 1st we need to sort the characters to get unique characters
chars=sorted(list(set(text)))
print(f'total no.of unique characters:{len(chars)}')
# lets map these unique characters
char_indices={c:i for i,c in enumerate(chars)}
indices_char={i:c for i,c in enumerate(chars)}
# Out:
# total no.of unique characters:37

# %%
# now we create a sequence from the text as we ae using lstms it learns from sequences to get vast traing data we use sliding windows wth a step of 3-5
# Here with creating sequence we are nothing but creating two arrays says for every let day 40 characters we need to fnd 41th character so we creating a "sentence[]" which contains characters of certain length say 40 and "next_char[]" will contain 41th character we continue this throught all the text with a step
max_len=40
step=3
sentences=[]
next_char=[]
for i in range(0,len(text)-max_len,3):
  sentences.append(text[i:i+max_len])
  next_char.append(text[i+max_len])
print(f'Number of training Sequences:{len(sentences)}')
# Out:
# Number of training Sequences:66654

# %%
# Now we will do integer encoding meaning we are converting
print("Integer Ecoding data for the embedding layer...")
# Now we create x,y where x is a 2d array of dimensions len(sentences),max_len i.e (66654,40) and y of shape 66654.
# These x,y are all zeros later we change the specific characters position "0" to its integer ID
x=np.zeros((len(sentences),max_len),dtype=np.int32)
y=np.zeros((len(sentences),),dtype=np.int32)

for i,sentence in enumerate(sentences):
  for t,char in enumerate(sentence):
    x[i,t]=char_indices[char]
  y[i]=char_indices[next_char[i]]
print(f'Id_s of x: {x}')
print(f'Target values Id_s: {y}')
# Out:
# Integer Ecoding data for the embedding layer...
# Id_s of x: [[16 19 28 ... 16 31 28]
#  [29 30  1 ... 30 18 15]
#  [13 19 30 ... 28  5  1]
#  ...
#  [15 24  1 ... 15 15 10]
#  [30 18 25 ...  0  0 13]
#  [31  1 18 ... 22 11 28]]
# Target values Id_s: [30 28 18 ...  0 22 15]

# %%
# Lets build our Emmbedding+LSTM Model
print("Building Model...")
model=Sequential([
    # in emdeddings layer we have teo parameters input_dim and out_Dim .
    # Here input_dim=vocabulary size i.e length(unique chars) and out_dim are the size of vector we want to compress into
    Embedding(input_dim=len(chars),output_dim=64),
    LSTM(256, return_sequences=False),
    Dropout(0.2),
    Dense(len(chars),activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",optimizer=RMSprop(learning_rate=0.001,clipnorm=1.0))
#categorical_crossentropy: Expects your target $Y$ to be a One-Hot Array. It expects to see something like [0, 0, 0, 1, 0, 0] to know the 4th character is the correct answer.
#sparse_categorical_crossentropy: Expects your target $Y$ to just be a Single Integer. It expects to see the number 3.
# Out:
# Building Model...

# %%
# Now lets Create a sample function to adjust the randomness of the predictions
def sample(preds,temp):
  preds=np.asarray(preds).astype("float64")
  preds=np.log(preds+ 1e-7)/temp # here we are chaging our values into log divides by temp to get values that have some significant difference between them
                                 # so that model won't go into loops selecting/predicting the same char with highest probbility
                                 #np.log(preds): We take the raw percentages (0.0 to 1.0) and convert them back into "logits" (raw mathematical scores).
                                 # temperature: We divide those scores by our temperature setting.
                                 # If Temp is low (0.2), it stretches the scores apart. The #1 likely character becomes massively dominant.
                                 # If Temp is high (1.5), it squishes the scores together. The #1 character and the #5 character suddenly look very similar.
                                 # we use 1e-7 to prevent getting value 0 as log(0) is mathematically undefined
  exp_preds=np.exp(preds) #Here we change he log values into prbabilities (float values) to choose the one randomly
  preds=exp_preds/np.sum(exp_preds)

  probas= np.random.multinomial(1,preds,1)
  return np.argmax(probas)

# %%
epochs = 50          # Increased to 50 for actual coherent text
batch_size = 512
generation_temp = 0.5 # Set your manual temperature here (0.4 - 0.6 is best)

print(f"Starting training for {epochs} epochs...")

for epoch in range(epochs):
    print(f"\n--- Epoch {epoch + 1} ---")

    # Train for one epoch
    model.fit(x, y, batch_size=batch_size, epochs=1)

    # Pick a random starting seed
    start_index = random.randint(0, len(text) - max_len - 1)
    sentence = text[start_index: start_index + max_len]

    print(f"\n--- Generating with Temperature: {generation_temp} ---")
    print(f'Seed: "{sentence}"\n')

    generated = sentence
    sys.stdout.write(generated)

    # Generate 100 characters
    for i in range(100):
        # Format the input for the Embedding layer
        x_pred = np.zeros((1, max_len), dtype=np.int32)
        for t, char in enumerate(sentence):
            x_pred[0, t] = char_indices[char]

        # Predict, Sample, and Decode
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, generation_temp)
        next_char = indices_char[next_index]

        # Slide the window
        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print("\n") # Add a final newline for clean formatting
# Out:
# Starting training for 50 epochs...
#
# --- Epoch 1 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - loss: 3.1647
#
# --- Generating with Temperature: 0.5 ---
# Seed: "d in the leash,
# to let him slip at will."
#
# d in the leash,
# to let him slip at will. tout teuu chet yon
# tou aers
# hte tose sars ten ttece ne wouttn
# ttod touun:
# es
# g: ant berunnes tuntto
#
#
# --- Epoch 2 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 2.6496
#
# --- Generating with Temperature: 0.5 ---
# Seed: " behold'st!
#
# aufidius:
# you keep a consta"
#
#  behold'st!
#
# aufidius:
# you keep a constace inco wal vanent one bas bere
# doul caveeng,
#
# wand setf som inen
# bans siuredd
# ant sore beakd tous h
#
#
# --- Epoch 3 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 2.4141
#
# --- Generating with Temperature: 0.5 ---
# Seed: "eir tides for their glories,
# an outward "
#
# eir tides for their glories,
# an outward mone int haml thith were on maron mane the tharis the hare me thes weril bare bere thil, is noule fa
#
#
# --- Epoch 4 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 2.2945
#
# --- Generating with Temperature: 0.5 ---
# Seed: "will.
#
# third citizen:
# we have power in o"
#
# will.
#
# third citizen:
# we have power in of ur the has has love noun on e ar the lome thin he the to af on rout tout my thous that woud the go
#
#
# --- Epoch 5 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 2.1935
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
# as to jove's statue, and the commons ma"
#
#
# as to jove's statue, and the commons mater the bestt the wrant ofe the mray sot to gisher our him meall his sath to fasd a and and the sere
#
#
# --- Epoch 6 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 2.1223
#
# --- Generating with Temperature: 0.5 ---
# Seed: "and curbs
# of more strong link asunder th"
#
# and curbs
# of more strong link asunder the tot the wins theter of nome the he mentt the frittlle the macend the fore then, corene to hes hath
#
#
# --- Epoch 7 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 2.0445
#
# --- Generating with Temperature: 0.5 ---
# Seed: "res up this fiend,
# to stop devoted chari"
#
# res up this fiend,
# to stop devoted charing that meret i have for ke coust when when near we hear he ather the mlarenter cominge the prenoter
#
#
# --- Epoch 8 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 1.9908
#
# --- Generating with Temperature: 0.5 ---
# Seed: "tice, but on the ministers
# that do distr"
#
# tice, but on the ministers
# that do distr thaind wors the cans the siglods whand and come the have wore wis on peren.
#
# acenius:
# where that an
#
#
# --- Epoch 9 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 1.9442
#
# --- Generating with Temperature: 0.5 ---
# Seed: " senator:
# you are a roman, are you?
#
# men"
#
#  senator:
# you are a roman, are you?
#
# menenius:
# whou have stord you bencenter and that stall.
#
# secinder:
# we dos eto to gors.
#
# tirsticen:
# he b
#
#
# --- Epoch 10 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 1.8848
#
# --- Generating with Temperature: 0.5 ---
# Seed: "hought thou hadst been resolute.
#
# second"
#
# hought thou hadst been resolute.
#
# second corlange:
# what you the bume to to kare as priested
# to his camen the comses to i all that gorsen tha
#
#
# --- Epoch 11 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 1.8375
#
# --- Generating with Temperature: 0.5 ---
# Seed: " paper
# and with thy scorns drew'st river"
#
#  paper
# and with thy scorns drew'st rivers, howh heard and fiis
# the sanes,
# the not the nother,
# where of the beeter with
# the sundore to shell
#
#
# --- Epoch 12 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 1.8071
#
# --- Generating with Temperature: 0.5 ---
# Seed: "?
#
# first murderer:
# no; then he will say "
#
# ?
#
# first murderer:
# no; then he will say the cromens and leares of the
# whill though stand of him.
#
# coriolanus:
# the stord with and the strold
#
#
# --- Epoch 13 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 1.7593
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s.
#
# sicinius:
# they are near the city?
#
# s"
#
# s.
#
# sicinius:
# they are near the city?
#
# sicinius:
# when, your porement and have them to the hather:
# and thes in the enss fire.
#
# coriolanus:
# fo
#
#
# --- Epoch 14 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 1.7202
#
# --- Generating with Temperature: 0.5 ---
# Seed: "onvenient peace. now, good aufidius,
# wer"
#
# onvenient peace. now, good aufidius,
# were where the gods the come to menely.
#
# sicinius:
# what's the reates thengers, there the gate
# to thee t
#
#
# --- Epoch 15 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 1.6775
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ow prove good seconds:
# 'tis for the foll"
#
# ow prove good seconds:
# 'tis for the follous with my shall be one me the suncesspore mear him trimes,
# i have man a prane be the leat and but
#
#
# --- Epoch 16 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 1.6520
#
# --- Generating with Temperature: 0.5 ---
# Seed: "zonian chin he drove
# the bristled lips b"
#
# zonian chin he drove
# the bristled lips be strackent is hove his there
# hath not on what i can ever were the peatres
# which he shall singine be
#
#
# --- Epoch 17 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 1.6293
#
# --- Generating with Temperature: 0.5 ---
# Seed: "menenius:
# there was a time when all the "
#
# menenius:
# there was a time when all the beation.
#
# sicinius:
# you see you the sting. why hear the senalle
# and his with the peather, and in the
#
#
# --- Epoch 18 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 1.6088
#
# --- Generating with Temperature: 0.5 ---
# Seed: "so, if
# he tell us his noble deeds, we mu"
#
# so, if
# he tell us his noble deeds, we must be stold,
# and the destore that dows betwith i say thee for the faint
# the volsted and the hast and
#
#
# --- Epoch 19 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 1.5793
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
# of what we chance to sentence.
#
# aedile:"
#
#
# of what we chance to sentence.
#
# aedile:
# well, worly, by the sentle to betare, and
# the camen of the hadd of our purine ame
# the beling of our
#
#
# --- Epoch 20 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - loss: 1.5450
#
# --- Generating with Temperature: 0.5 ---
# Seed: "with whom we may articulate,
# for their o"
#
# with whom we may articulate,
# for their of thee, should strokn to dour,
# they beserve them to the of our comen toon
# worgh us you be cann strom
#
#
# --- Epoch 21 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - loss: 1.5316
#
# --- Generating with Temperature: 0.5 ---
# Seed: "espected not them;
# and, he returning to "
#
# espected not them;
# and, he returning to the enemaring in
# the foring to more your leaven of the canness,
# i wall so be him to the himpelf and
#
#
# --- Epoch 22 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 1.5033
#
# --- Generating with Temperature: 0.5 ---
# Seed: "solace: and
# believe't not lightly--thoug"
#
# solace: and
# believe't not lightly--though the offordeds,
# who he stand of the mush, that i have brees
# his consult that thou shall the mellon'
#
#
# --- Epoch 23 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - loss: 1.4810
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
# and venomous to thine eyes. my sometime"
#
#
# and venomous to thine eyes. my sometime to have made
# that maling it strat make him to the strreate,
# and the had be arm strong of the wall h
#
#
# --- Epoch 24 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - loss: 1.4592
#
# --- Generating with Temperature: 0.5 ---
# Seed: "d thy tribe before him,
# his good sword i"
#
# d thy tribe before him,
# his good sword it the canness beseen would the shold the here as my stance.
#
# menenius:
# i made a prower him to the ac
#
#
# --- Epoch 25 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 1.4281
#
# --- Generating with Temperature: 0.5 ---
# Seed: " and in corioli, let me say,
# i cannot sp"
#
#  and in corioli, let me say,
# i cannot speak, when he head not to have
# the this it the stanter and stroke for my the gates;
# the but the valia
#
#
# --- Epoch 26 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - loss: 1.4112
#
# --- Generating with Temperature: 0.5 ---
# Seed: "u will not? prithee, tell my master what"
#
# u will not? prithee, tell my master what
# he was soing to be the dedire to the curire to the thee god compeing them
# that the at will service
#
#
# --- Epoch 27 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 1.3982
#
# --- Generating with Temperature: 0.5 ---
# Seed: "n
# we pout upon the morning, are unapt
# to"
#
# n
# we pout upon the morning, are unapt
# to be off dess and to the people pass,
# and the people to this porition with him,
# and the had will not
#
#
# --- Epoch 28 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 1.3697
#
# --- Generating with Temperature: 0.5 ---
# Seed: " many so minded,
# wave thus, to express h"
#
#  many so minded,
# wave thus, to express his here their to your compersed to the hishers
# and the thou dest the shame of our stands:
# his yet to
#
#
# --- Epoch 29 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 1.3411
#
# --- Generating with Temperature: 0.5 ---
# Seed: "news? what news?
#
# cominius:
# you have hol"
#
# news? what news?
#
# cominius:
# you have hold sonce more to hath but there
# that is i am the out of state, and the dome,
# i have not to the compes
#
#
# --- Epoch 30 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - loss: 1.3068
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ch eyes the widows in corioli wear,
# and "
#
# ch eyes the widows in corioli wear,
# and it that worshy to shall can thee fair
# with marters fillows her heread in of her that
# know the most o
#
#
# --- Epoch 31 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 1.2884
#
# --- Generating with Temperature: 0.5 ---
# Seed: "e consul.
#
# sixth citizen:
# he has done no"
#
# e consul.
#
# sixth citizen:
# he has done not to his trance, and in shall
# on thouth to senter them this part and matter
# speak this love my love
#
#
# --- Epoch 32 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 1.2718
#
# --- Generating with Temperature: 0.5 ---
# Seed: "e these sad designs
# to him that hath mor"
#
# e these sad designs
# to him that hath more toubther and for well.
#
# first senator:
# before the people of rome.
#
# coriolanus:
# whore own exess?
#
# l
#
#
# --- Epoch 33 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 1.2409
#
# --- Generating with Temperature: 0.5 ---
# Seed: "hich didst unworthy slaughter upon other"
#
# hich didst unworthy slaughter upon other.
#
# lary anne:
# the grouse to gromaver.
#
# coriolanus:
# what see your corselfsen for the hereman.
#
# brutus
#
#
# --- Epoch 34 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - loss: 1.2181
#
# --- Generating with Temperature: 0.5 ---
# Seed: "t?
#
# volsce:
# nicanor? no.
#
# roman:
# the sam"
#
# t?
#
# volsce:
# nicanor? no.
#
# roman:
# the same of me?
#
# brutus:
# the power of herm percits that should be speen
# that a bear to the city be say be a
#
#
# --- Epoch 35 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 1.1737
#
# --- Generating with Temperature: 0.5 ---
# Seed: "till without him.
#
# aedile:
# worthy tribun"
#
# till without him.
#
# aedile:
# worthy tribunes, and the hame out for the off
# it was the gods that and in shall will to be
# ore the tame with a cu
#
#
# --- Epoch 36 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - loss: 1.1641
#
# --- Generating with Temperature: 0.5 ---
# Seed: "st yourself you be incensed, we'll put y"
#
# st yourself you be incensed, we'll put your tribunes,
# may be the sunderies and a power.
#
# menenius:
# hath most it partion word to the repors.
#
#
#
# --- Epoch 37 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 149s 1s/step - loss: 1.1469
#
# --- Generating with Temperature: 0.5 ---
# Seed: "tinate.
# what is that curt'sy worth? or t"
#
# tinate.
# what is that curt'sy worth? or these are
# the gropst to the puperace wits and trubtle
# to his propive to seep the faullt bear we cause
#
#
# --- Epoch 38 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - loss: 1.1213
#
# --- Generating with Temperature: 0.5 ---
# Seed: "y to the roman?
#
# lieutenant:
# i do not kn"
#
# y to the roman?
#
# lieutenant:
# i do not know the hissonour citizens, and truth
# of a have did concessed my lords, here be
# thou brets the marven
#
#
# --- Epoch 39 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - loss: 1.0916
#
# --- Generating with Temperature: 0.5 ---
# Seed: "oreign recreant, be led
# with manacles th"
#
# oreign recreant, be led
# with manacles this parricions! who god thee,
# thou whose the gods he as chost him their
# death in this know'd our comm
#
#
# --- Epoch 40 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - loss: 1.0621
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s:
# not according to the prayer of the pe"
#
# s:
# not according to the prayer of the people,
# which and the tombul this contaling tongue,
# and the with of athiance stenchame with thee, of t
#
#
# --- Epoch 41 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 1.0372
#
# --- Generating with Temperature: 0.5 ---
# Seed: "y
# in all his own desires; nay, let him c"
#
# y
# in all his own desires; nay, let him compods.
#
# menenius:
# the senators, betwer that let them string,
# and the friend word on the the poor lo
#
#
# --- Epoch 42 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 1.0049
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ch we being members, should bring oursel"
#
# ch we being members, should bring ourselfes
# than stenk the meanish'd the chilingeds sown,
# and shall since thy particers and reasenours,
# i wi
#
#
# --- Epoch 43 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 0.9847
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ve this faint puling and lament as i do,"
#
# ve this faint puling and lament as i do,
# in that would not seel me hath behord that
# i was a creat berore therethich our resselies, sent, but
#
#
# --- Epoch 44 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - loss: 0.9578
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
# marcius:
# hang 'em! they say!
# they'll si"
#
#
# marcius:
# hang 'em! they say!
# they'll sit?
#
# sicinius:
# the comming made he had hand would have hath surs:
# he with his dencleds by the general
#
#
# --- Epoch 45 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - loss: 0.9368
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ll what he would have
# but kneels and hol"
#
# ll what he would have
# but kneels and holl to the this to her deadt;
# who love the warr'd him hather sad be the
# saison's sparce; to dow the fl
#
#
# --- Epoch 46 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - loss: 0.9131
#
# --- Generating with Temperature: 0.5 ---
# Seed: "where dwellest thou?
#
# coriolanus:
# under "
#
# where dwellest thou?
#
# coriolanus:
# under the commin may than to the suchion
# of the senater word, chis merchy words that would he bland in him
#
#
# --- Epoch 47 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 146s 1s/step - loss: 0.8873
#
# --- Generating with Temperature: 0.5 ---
# Seed: "yes, yes; the senate
# has letters from th"
#
# yes, yes; the senate
# has letters from these's in eyes before it have
# the offends ou the patil.
#
# second servingman:
# what anter not stall of t
#
#
# --- Epoch 48 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.8725
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ing,
# self-loving,--
#
# sicinius:
# and affec"
#
# ing,
# self-loving,--
#
# sicinius:
# and affeccind made, and you so this wall be
# canded them to the cownss.
#
# sicinius:
# hers come to the himp.
#
# sic
#
#
# --- Epoch 49 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - loss: 0.8506
#
# --- Generating with Temperature: 0.5 ---
# Seed: " care for you like fathers,
# when you cur"
#
#  care for you like fathers,
# when you curse them, that i think it then,
# his liasest it us a cattle coriolanus,
# to be survies tood for our pea
#
#
# --- Epoch 50 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - loss: 0.8276
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s
# a good construction. i raised him, and"
#
# s
# a good construction. i raised him, and have done
# to the figh and stake fair of such a man,
# well steend it.
#
# sicinius:
# indist to forgh.
#
# ma
