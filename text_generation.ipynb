# %% [markdown]
# <a href="https://colab.research.google.com/github/Yashwant-SriSai/Shakesphere_Copy_Cat/blob/main/text_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imports
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Embedding,Dropout
from tensorflow.keras.optimizers import RMSprop
import random
import sys

# %%
#Load he Shakesphere's Dataset
print("Downloading Sakesphere's Data....")
path = tf.keras.utils.get_file('shakespeare.txt',
    origin='https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt')
with open(path,encoding="utf-8") as f:
  text=f.read().lower() # why lower? so that model won't have to remember that both "a" and "A" or same.
# lets take first 200,000 characters for our vocabulary
text=text[:200000]
print(f'Corpus Length:{len(text)}')
# Out:
# Downloading Sakesphere's Data....
# Corpus Length:200000

# %%
#Map characters to integers
# 1st we need to sort the characters to get unique characters
chars=sorted(list(set(text)))
print(f'total no.of unique characters:{len(chars)}')
# lets map these unique characters
char_indices={c:i for i,c in enumerate(chars)}
indices_char={i:c for i,c in enumerate(chars)}
# Out:
# total no.of unique characters:37

# %%
# now we create a sequence from the text as we ae using lstms it learns from sequences to get vast traing data we use sliding windows wth a step of 3-5
# Here with creating sequence we are nothing but creating two arrays says for every let day 40 characters we need to fnd 41th character so we creating a "sentence[]" which contains characters of certain length say 40 and "next_char[]" will contain 41th character we continue this throught all the text with a step
max_len=40
step=3
sentences=[]
next_char=[]
for i in range(0,len(text)-max_len,3):
  sentences.append(text[i:i+max_len])
  next_char.append(text[i+max_len])
print(f'Number of training Sequences:{len(sentences)}')
# Out:
# Number of training Sequences:66654

# %%
# Now we will do integer encoding meaning we are converting
print("Integer Ecoding data for the embedding layer...")
# Now we create x,y where x is a 2d array of dimensions len(sentences),max_len i.e (66654,40) and y of shape 66654.
# These x,y are all zeros later we change the specific characters position "0" to its integer ID
x=np.zeros((len(sentences),max_len),dtype=np.int32)
y=np.zeros((len(sentences),),dtype=np.int32)

for i,sentence in enumerate(sentences):
  for t,char in enumerate(sentence):
    x[i,t]=char_indices[char]
  y[i]=char_indices[next_char[i]]
print(f'Id_s of x: {x}')
print(f'Target values Id_s: {y}')
# Out:
# Integer Ecoding data for the embedding layer...
# Id_s of x: [[16 19 28 ... 16 31 28]
#  [29 30  1 ... 30 18 15]
#  [13 19 30 ... 28  5  1]
#  ...
#  [15 24  1 ... 15 15 10]
#  [30 18 25 ...  0  0 13]
#  [31  1 18 ... 22 11 28]]
# Target values Id_s: [30 28 18 ...  0 22 15]

# %%
# Lets build our Emmbedding+LSTM Model
print("Building Model...")
model=Sequential([
    # in emdeddings layer we have teo parameters input_dim and out_Dim .
    # Here input_dim=vocabulary size i.e length(unique chars) and out_dim are the size of vector we want to compress into
    Embedding(input_dim=len(chars),output_dim=64),
    LSTM(256, return_sequences=False),
    Dropout(0.2),
    Dense(len(chars),activation="softmax")
])
model.compile(loss="sparse_categorical_crossentropy",optimizer=RMSprop(learning_rate=0.001,clipnorm=1.0))
#categorical_crossentropy: Expects your target $Y$ to be a One-Hot Array. It expects to see something like [0, 0, 0, 1, 0, 0] to know the 4th character is the correct answer.
#sparse_categorical_crossentropy: Expects your target $Y$ to just be a Single Integer. It expects to see the number 3.
# Out:
# Building Model...

# %%
# Now lets Create a sample function to adjust the randomness of the predictions
def sample(preds,temp):
  preds=np.asarray(preds).astype("float64")
  preds=np.log(preds+ 1e-7)/temp # here we are chaging our values into log divides by temp to get values that have some significant difference between them
                                 # so that model won't go into loops selecting/predicting the same char with highest probbility
                                 #np.log(preds): We take the raw percentages (0.0 to 1.0) and convert them back into "logits" (raw mathematical scores).
                                 # temperature: We divide those scores by our temperature setting.
                                 # If Temp is low (0.2), it stretches the scores apart. The #1 likely character becomes massively dominant.
                                 # If Temp is high (1.5), it squishes the scores together. The #1 character and the #5 character suddenly look very similar.
                                 # we use 1e-7 to prevent getting value 0 as log(0) is mathematically undefined
  exp_preds=np.exp(preds) #Here we change he log values into prbabilities (float values) to choose the one randomly
  preds=exp_preds/np.sum(exp_preds)

  probas= np.random.multinomial(1,preds,1)
  return np.argmax(probas)

# %%
epochs = 50          # Increased to 50 for actual coherent text
batch_size = 512
generation_temp = 0.5 # Set your manual temperature here (0.4 - 0.6 is best)

print(f"Starting training for {epochs} epochs...")

for epoch in range(epochs):
    print(f"\n--- Epoch {epoch + 1} ---")

    # Train for one epoch
    model.fit(x, y, batch_size=batch_size, epochs=1)

    # Pick a random starting seed
    start_index = random.randint(0, len(text) - max_len - 1)
    sentence = text[start_index: start_index + max_len]

    print(f"\n--- Generating with Temperature: {generation_temp} ---")
    print(f'Seed: "{sentence}"\n')

    generated = sentence
    sys.stdout.write(generated)

    # Generate 100 characters
    for i in range(100):
        # Format the input for the Embedding layer
        x_pred = np.zeros((1, max_len), dtype=np.int32)
        for t, char in enumerate(sentence):
            x_pred[0, t] = char_indices[char]

        # Predict, Sample, and Decode
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds, generation_temp)
        next_char = indices_char[next_index]

        # Slide the window
        generated += next_char
        sentence = sentence[1:] + next_char

        sys.stdout.write(next_char)
        sys.stdout.flush()
    print("\n") # Add a final newline for clean formatting
# Out:
# Starting training for 50 epochs...
#
# --- Epoch 1 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 130s 971ms/step - loss: 3.0306
#
# --- Generating with Temperature: 0.5 ---
# Seed: "lse thy person,
# our comfort in the count"
#
# lse thy person,
# our comfort in the count ta hea the iar oh ate he haue, th atar oate aiis oate thie thie the th he h ioa thee he aaan he oar
#
#
# --- Epoch 2 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 929ms/step - loss: 2.5635
#
# --- Generating with Temperature: 0.5 ---
# Seed: "th
# sighs; and conjure thee to pardon rom"
#
# th
# sighs; and conjure thee to pardon rome man the the neled the the se bet ther foud thas to toud are wo das dous tou ce ouant the ane won a
#
#
# --- Epoch 3 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 124s 947ms/step - loss: 2.3791
#
# --- Generating with Temperature: 0.5 ---
# Seed: "this true which they so seem to fear. go"
#
# this true which they so seem to fear. gold then thicg u thas the the is tius tout be hison fou gof here the the ly as the hou he thek wous t
#
#
# --- Epoch 4 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 932ms/step - loss: 2.2606
#
# --- Generating with Temperature: 0.5 ---
# Seed: "y his rare example made the coward
# turn "
#
# y his rare example made the coward
# turn noure bee, the sice mans the howe breess to the mere i hime and whe sou sele mours counce hame the m
#
#
# --- Epoch 5 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 928ms/step - loss: 2.1734
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ner.
#
# gloucester:
# then bid me kill mysel"
#
# ner.
#
# gloucester:
# then bid me kill myseld to hith thou tas the hand the pare the ceapet the fale to the sell the the seand a to late the lav
#
#
# --- Epoch 6 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 932ms/step - loss: 2.1030
#
# --- Generating with Temperature: 0.5 ---
# Seed: " speak with coriolanus.
#
# first senator:
# "
#
#  speak with coriolanus.
#
# first senator:
# where dere, come the hore the pains the mome,
# and male and the prave are and you mage, of the gorst
#
#
# --- Epoch 7 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 923ms/step - loss: 2.0344
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s,
# i have fought with thee: so often has"
#
# s,
# i have fought with thee: so often has rament, and wind to the pray the cithers and the cordebund, and willares seall fore,
# where to the p
#
#
# --- Epoch 8 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 923ms/step - loss: 1.9812
#
# --- Generating with Temperature: 0.5 ---
# Seed: "e that i know.
#
# volumnia:
# he had, before"
#
# e that i know.
#
# volumnia:
# he had, befored the lome, i ampile hath dore bet the hapl he rake he shall his ford the condone the your hare dor
#
#
# --- Epoch 9 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 937ms/step - loss: 1.9282
#
# --- Generating with Temperature: 0.5 ---
# Seed: "k you.
# i mean to stride your steed, and "
#
# k you.
# i mean to stride your steed, and shan he to the he our his live hast connous and the his ard the dad the weard shereces this do shenc
#
#
# --- Epoch 10 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 939ms/step - loss: 1.8797
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s all of fury, shall lift up
# their rotte"
#
# s all of fury, shall lift up
# their rotter the his meare well'd wo made and to home,
# and the tourd wall me agrert with a that so bote of the
#
#
# --- Epoch 11 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 936ms/step - loss: 1.8376
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ning him:
# methinks i see him stamp thus,"
#
# ning him:
# methinks i see him stamp thus, wan the fair be this for then will on thement and the pall that and singel him patting the matten b
#
#
# --- Epoch 12 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 930ms/step - loss: 1.7940
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
# the noble sister of publicola,
# the moon"
#
#
# the noble sister of publicola,
# the moon to hin hear marcatus, and wat to the deople,
# the gens to him seak
# the lots and hemp.
#
# gloucester:
# h
#
#
# --- Epoch 13 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 930ms/step - loss: 1.7610
#
# --- Generating with Temperature: 0.5 ---
# Seed: " tell him so.
#
# second murderer:
# i pray t"
#
#  tell him so.
#
# second murderer:
# i pray to be the deate.
#
# first sorder:
# the people to the to have the prople hor the varse of the nom that fo
#
#
# --- Epoch 14 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 934ms/step - loss: 1.7266
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ke with fear and sorrow;
# making the moth"
#
# ke with fear and sorrow;
# making the mother
# in the cansent sim,
# whobe shall be and some i marcester.
#
# cominius:
# well, so he canseble.
#
# farst
#
#
# --- Epoch 15 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 935ms/step - loss: 1.6974
#
# --- Generating with Temperature: 0.5 ---
# Seed: "mate, her womb's increase,
# and treasure "
#
# mate, her womb's increase,
# and treasure of the themest been and be some to the me
# what i done them.
#
# socinius:
# and my lest and not.
#
# meneniu
#
#
# --- Epoch 16 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 924ms/step - loss: 1.6661
#
# --- Generating with Temperature: 0.5 ---
# Seed: "go in,
# and take our friendly senators by"
#
# go in,
# and take our friendly senators by shought
# that shall consuling of where an worther
# that to deast to and marcius with so him;
# be not s
#
#
# --- Epoch 17 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 921ms/step - loss: 1.6352
#
# --- Generating with Temperature: 0.5 ---
# Seed: "
# from slaves that apes would beat! pluto"
#
#
# from slaves that apes would beat! plutore,
# the farse his fared have he sae in shall on you to him here:
# what we have dead the peeplers be t
#
#
# --- Epoch 18 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 918ms/step - loss: 1.6086
#
# --- Generating with Temperature: 0.5 ---
# Seed: "legs, by the good gods,
# i'ld with thee e"
#
# legs, by the good gods,
# i'ld with thee eres and that and to think
# that shall the corin me him, to the to song.
#
# brutus:
# let the mest that ar
#
#
# --- Epoch 19 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 120s 920ms/step - loss: 1.5817
#
# --- Generating with Temperature: 0.5 ---
# Seed: "n them to give.
#
# brutus:
# come, we'll inf"
#
# n them to give.
#
# brutus:
# come, we'll inforded be i peirties i cannot the will the reath
# of the peater betore i his cannot the thee
# the senot
#
#
# --- Epoch 20 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 921ms/step - loss: 1.5558
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ere,--this, who, like a block, hath deni"
#
# ere,--this, who, like a block, hath dening, and his the him
# his countering, the prack of him word,
# thous is charted of his caunter plows,
# wh
#
#
# --- Epoch 21 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 928ms/step - loss: 1.5345
#
# --- Generating with Temperature: 0.5 ---
# Seed: " forth greater themes
# for insurrection's"
#
#  forth greater themes
# for insurrection's this and the mant of the suef
# with dis in the purse of the state of prack
# on the have the exess of
#
#
# --- Epoch 22 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 125s 952ms/step - loss: 1.5098
#
# --- Generating with Temperature: 0.5 ---
# Seed: " end o' the table; no
# question asked him"
#
#  end o' the table; no
# question asked him to the them there he their reconds
# with but my more than deep the have stands than you shall he was
#
#
# --- Epoch 23 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 929ms/step - loss: 1.4871
#
# --- Generating with Temperature: 0.5 ---
# Seed: "eat hostilius, here was king;
# of the sam"
#
# eat hostilius, here was king;
# of the same to his grient you soung, and the shall
# see he benies dis and to marcius is strong;
# o have done of
#
#
# --- Epoch 24 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 124s 944ms/step - loss: 1.4666
#
# --- Generating with Temperature: 0.5 ---
# Seed: "o does the wolf love?
#
# sicinius:
# the lam"
#
# o does the wolf love?
#
# sicinius:
# the lame us was to the stratt of the hath and there
# that have he deed here, he strike and to the garing pai
#
#
# --- Epoch 25 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 929ms/step - loss: 1.4370
#
# --- Generating with Temperature: 0.5 ---
# Seed: " to
# front his revenges with the easy gro"
#
#  to
# front his revenges with the easy gromes,
# i that you the catize them we daded
# the senate and to the people,
# by the exelor to his loves a
#
#
# --- Epoch 26 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 924ms/step - loss: 1.4174
#
# --- Generating with Temperature: 0.5 ---
# Seed: "f hecuba,
# when she did suckle hector, lo"
#
# f hecuba,
# when she did suckle hector, love to the mother
# who have stand of him to hear he did of die in the comses,
# and we have sunder demer
#
#
# --- Epoch 27 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 932ms/step - loss: 1.3939
#
# --- Generating with Temperature: 0.5 ---
# Seed: "admits
# a good construction. i raised him"
#
# admits
# a good construction. i raised him!
# what not is not strake and so her hearth
# 'tis not ladies and the mine of the failles,
# what we are
#
#
# --- Epoch 28 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 931ms/step - loss: 1.3711
#
# --- Generating with Temperature: 0.5 ---
# Seed: "n they are not dead:
# but dead they are, "
#
# n they are not dead:
# but dead they are, sich a man an shake o' the rest,
# he was their it gott me our at to some in a man partient
# what you h
#
#
# --- Epoch 29 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 923ms/step - loss: 1.3472
#
# --- Generating with Temperature: 0.5 ---
# Seed: " 'deny not.' let the volsces
# plough rome"
#
#  'deny not.' let the volsces
# plough rome.
#
# virgilia:
# he was a clarest in the mink of his trither,
# i have weet in the catitol hangs,
# that you
#
#
# --- Epoch 30 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 937ms/step - loss: 1.3278
#
# --- Generating with Temperature: 0.5 ---
# Seed: "nting, which i doubt not but
# our rome wi"
#
# nting, which i doubt not but
# our rome will so his coring the heaths:
# and some be sward for the people.
#
# gloucester:
# you see he have deners o
#
#
# --- Epoch 31 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 942ms/step - loss: 1.3026
#
# --- Generating with Temperature: 0.5 ---
# Seed: "coriolanus.
#
# brutus:
# he consul!
#
# citizen"
#
# coriolanus.
#
# brutus:
# he consul!
#
# citizens:
# the not of cannot me that swart loves of the commiss.
# who lod me the hors his conseline strange,
#
#
# --- Epoch 32 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 124s 943ms/step - loss: 1.2779
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s, his name?
#
# coriolanus:
# by jupiter! fo"
#
# s, his name?
#
# coriolanus:
# by jupiter! for the senate his seeas and
# city be hath mel of the sear.
#
# second senator:
# o be had hear end him our
#
#
# --- Epoch 33 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 936ms/step - loss: 1.2548
#
# --- Generating with Temperature: 0.5 ---
# Seed: "iscarries
# shall be the general's fault, "
#
# iscarries
# shall be the general's fault, they we drisped
# the man chars upon the people, show we have
# the houses of the ears, they lart us so
#
#
# --- Epoch 34 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 125s 957ms/step - loss: 1.2287
#
# --- Generating with Temperature: 0.5 ---
# Seed: " where he was like to find fame. to a cr"
#
#  where he was like to find fame. to a crown and deast,
# the proming prove the proppessed sone, verient and from us.
#
# menenius:
# the ender of t
#
#
# --- Epoch 35 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 941ms/step - loss: 1.2023
#
# --- Generating with Temperature: 0.5 ---
# Seed: "im like a dog, but for
# disturbing the lo"
#
# im like a dog, but for
# disturbing the lord and the stander dool,
# the proptest and so slow'd of all the catt.
#
# sicinius:
# well, go dithor.
#
# se
#
#
# --- Epoch 36 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 120s 919ms/step - loss: 1.1770
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ot the common people.
#
# second officer:
# f"
#
# ot the common people.
#
# second officer:
# for thou shanter of their partion.
#
# menenius:
# i was i peace of their comionius,
# that will i can the s
#
#
# --- Epoch 37 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 932ms/step - loss: 1.1526
#
# --- Generating with Temperature: 0.5 ---
# Seed: "tudinous tongue; let them not lick
# the s"
#
# tudinous tongue; let them not lick
# the should not preseet and my stall as fat heart
# that cannot be sice.
#
# coriolanus:
# what should me fair my
#
#
# --- Epoch 38 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 122s 928ms/step - loss: 1.1268
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s:
# come, sir, come, we know you well eno"
#
# s:
# come, sir, come, we know you well enour farrud.
#
# sicinius:
# why stow dode to dome, and there was first so.
#
# sicinius:
# where it the will to
#
#
# --- Epoch 39 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 120s 917ms/step - loss: 1.1029
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ugh it were as virtuous
# to lie as to liv"
#
# ugh it were as virtuous
# to lie as to live whon so him to the world
# here pease my commanded then that how disco!
#
# sicinius:
# the grates of cha
#
#
# --- Epoch 40 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 924ms/step - loss: 1.0779
#
# --- Generating with Temperature: 0.5 ---
# Seed: "!
#
# citizens:
# yield, marcius, yield!
#
# men"
#
# !
#
# citizens:
# yield, marcius, yield!
#
# menenius:
# he will not pother the people and the grops,
# so mad i am a prace? which we as volssin
# if have
#
#
# --- Epoch 41 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 922ms/step - loss: 1.0554
#
# --- Generating with Temperature: 0.5 ---
# Seed: "of your honour: no; our suit
# is that you"
#
# of your honour: no; our suit
# is that you shake some may an all reave,
# that lay state thee strung, and have fore.
#
# volumnia:
# o'r son, to the
#
#
# --- Epoch 42 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 124s 944ms/step - loss: 1.0285
#
# --- Generating with Temperature: 0.5 ---
# Seed: ", not fierce and terrible
# only in stroke"
#
# , not fierce and terrible
# only in strokes, and the painit my for the people,
# the benow of the sconser'd to the cannot
# me will be hearthy hal
#
#
# --- Epoch 43 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 127s 966ms/step - loss: 1.0057
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ful.
# i charge you, as you hope to have r"
#
# ful.
# i charge you, as you hope to have reselveds,
# then naturals seeving thee to rome strong
# on on the muther--ithing one the comm of butter
#
#
#
# --- Epoch 44 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 124s 950ms/step - loss: 0.9813
#
# --- Generating with Temperature: 0.5 ---
# Seed: "iolanus:
# ha!
#
# aufidius:
# no more.
#
# coriol"
#
# iolanus:
# ha!
#
# aufidius:
# no more.
#
# coriolanus:
# hears me, you; the commen of the meation;
# whother bre he power and to shall be consul,
# but tho
#
#
# --- Epoch 45 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 125s 952ms/step - loss: 0.9564
#
# --- Generating with Temperature: 0.5 ---
# Seed: "that all at once,
# you, my good friends,'"
#
# that all at once,
# you, my good friends,' is a know the repull,
# o ke have but a bungree, and the fore
# han the dear on the senate flatters.
#
# m
#
#
# --- Epoch 46 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 125s 955ms/step - loss: 0.9323
#
# --- Generating with Temperature: 0.5 ---
# Seed: "t go; there's few or none will entertain"
#
# t go; there's few or none will entertains
# to the faites of the people, shollit, and trueff
# thing worthy made mine beciest of the liess
# of th
#
#
# --- Epoch 47 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 121s 921ms/step - loss: 0.9092
#
# --- Generating with Temperature: 0.5 ---
# Seed: "rected son?
# then let the pebbles on the "
#
# rected son?
# then let the pebbles on the peatore, and your restrame
# the neither our gonsor them worthy to do it.
#
# sicinius:
# this mad cantall
#
#
# --- Epoch 48 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 120s 917ms/step - loss: 0.8859
#
# --- Generating with Temperature: 0.5 ---
# Seed: "s:
# mark you that?
#
# coriolanus:
# to brag u"
#
# s:
# mark you that?
#
# coriolanus:
# to brag undell.
#
# menenius:
# i am not a bood your gannow on the people,
# and the will sirpon him her here:
# in hi
#
#
# --- Epoch 49 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 124s 947ms/step - loss: 0.8635
#
# --- Generating with Temperature: 0.5 ---
# Seed: "ould judge
# what 'twere to lose it, and b"
#
# ould judge
# what 'twere to lose it, and before the death
# on the people against the death our goness,
# me's the report it who he's here her hay
#
#
# --- Epoch 50 ---
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 123s 939ms/step - loss: 0.8418
#
# --- Generating with Temperature: 0.5 ---
# Seed: "his law commanded
# that thou shalt do no "
#
# his law commanded
# that thou shalt do no mess an's thy live
# i think of on the changerand and the should
# show that he did from which he discon

# %% [markdown]
# ### Save the trained model
#
# We will save the model in the Keras native format (`.keras`), which is the recommended approach for Keras 3. This format saves the model's architecture, weights, and training configuration (including the optimizer state).

# %%
model_path = 'shakespeare_text_generator.keras'
model.save(model_path)
print(f"Model saved to {model_path}")
# Out:
# Model saved to shakespeare_text_generator.keras

# %% [markdown]
# ### Load the saved model and perform inference
#
# First, we load the model. Then, to demonstrate inference, we will take a random seed sentence from the original text, prepare it as input, and use the loaded model to predict the next character, similar to how it's done during text generation.

# %%
import tensorflow as tf
import numpy as np
import random
from google.colab import drive

# Mount Google Drive
drive.mount('/content/gdrive')

# Define the path to the saved model in Google Drive
model_path = '/content/gdrive/MyDrive/shakespeare_text_generator.keras'

# Load the saved model
loaded_model = tf.keras.models.load_model(model_path)
print("Model loaded successfully!")

# Define max_len, char_indices, and indices_char if they are not globally accessible after loading a fresh notebook.
# In this execution context, they should be available from previous cells.
# However, for robustness, one might re-define them or ensure they are passed correctly.
# Assuming `max_len`, `char_indices`, `indices_char`, and `text` are still in scope.

# Pick a random starting seed for inference
start_index = random.randint(0, len(text) - max_len - 1)
seed_sentence = text[start_index: start_index + max_len]

print(f'\n--- Performing inference with loaded model ---')
print(f'Seed: "{seed_sentence}"')

# Prepare the input for the loaded model
x_pred_loaded = np.zeros((1, max_len), dtype=np.int32)
for t, char in enumerate(seed_sentence):
    x_pred_loaded[0, t] = char_indices[char]

# Predict the next character using the loaded model
# Use a default temperature for sampling, e.g., 0.5
generation_temp = 0.5
preds_loaded = loaded_model.predict(x_pred_loaded, verbose=0)[0]
next_index_loaded = sample(preds_loaded, generation_temp)
next_char_loaded = indices_char[next_index_loaded]

print(f'Predicted next character: "{next_char_loaded}"')
print(f'Full generated text (seed + predicted char): "{seed_sentence + next_char_loaded}"')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Model loaded successfully!
#
# --- Performing inference with loaded model ---
# Seed: "loucester:
# margaret.
#
# queen margaret:
# ri"
# Predicted next character: "c"
# Full generated text (seed + predicted char): "loucester:
# margaret.
#
# queen margaret:
# ric"
